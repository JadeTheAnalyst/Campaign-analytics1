# %% [markdown]
# ### 1. Basic Pandas concepts
#
# Pandas stands for “Python Data Analysis Library”. It is a high-level data manipulation tool developed by Wes McKinney. It is built on the Numpy package and its key data structure is called the DataFrame. DataFrames allow you to store and manipulate tabular data in rows of observations and columns of variables.

# %%
import pandas as pd # pandas provides indexing structure and data manipulation functionality

# %% [markdown]
# #### 1.1 Reading data
# Remember that local python runs in memory. If you're on a Windows machine, you can open the task manager to the memory tab and then run the below section. You should see a big spike in your memory usage as the dataframe loads.
#
# We recommend your data be in csv format if you're working with pandas. The `read_csv` function makes it really easy to read in data. File name is the only required argument.

# %%
campaign = pd.read_csv("campaign.csv")

# %%
campaign.shape
# Out:
# (10022, 10)

# %% [markdown]
# #### 1.2 Examine the data
#
# `.shape` is an *attribute* of a DataFrame object. This means it's a built-it in characteristic automatically available for all DataFrames.
#
# Specifically, `.shape` shows the dimensions of the df as rows, columns. In python, rows are axis=0 and columns are axis=1.

# %%
campaign.shape
# Out:
# (10022, 10)

# %% [markdown]
# `.columns` shows the names of the columns in your dataframe.
# You can tell *attributes* and *methods* apart because the latter requires `()`.
#
# *Note:* .columns returns an index object, which does not have great formatting when displayed. Lists have better default formatting. As the name implies, `tolist()` converts the `columns` result to a list.

# %%
campaign.columns
# Out:
# Index(['user_id', 'date_served', 'marketing_channel', 'test_control',
#        'converted', 'language_preferred', 'age_group', 'date_subscribed',
#        'date_canceled', 'is_retained'],
#       dtype='object')

# %% [markdown]
# `.head(n)` shows the first n rows of the dataframe. If you omit n, it will return the first 5 rows.
#
# By default, ipython notebook shows 60 rows and 20 columns when you preview a pandas dataframe. To modify this default, use `pd.set_option()`, e.g. `pd.set_option("display.max_rows",100)` or `pd.set_option("display.max_columns",100)`

# %%
# look at the data
campaign.head(100)
# Out:
#        user_id date_served marketing_channel     test_control  converted  \
# 0   a100000029    1/1/2018         House Ads  personalization       True
# 1   a100000030    1/1/2018         House Ads  personalization       True
# 2   a100000031    1/1/2018         House Ads  personalization       True
# 3   a100000032    1/1/2018         House Ads  personalization       True
# 4   a100000033    1/1/2018         House Ads  personalization       True
# ..         ...         ...               ...              ...        ...
# 95  a100000104    1/5/2018         House Ads          control       True
# 96  a100000104    1/4/2018         House Ads          control      False
# 97  a100000105    1/5/2018         House Ads          control       True
# 98  a100000105    1/4/2018         House Ads          control      False
# 99  a100000107    1/5/2018         House Ads          control       True
#
#    language_preferred    age_group date_subscribed date_canceled is_retained
# 0             English   0-18 years        1/1/2018           NaN        True
# 1             English  19-24 years        1/1/2018           NaN        True
# 2             English  24-30 years        1/1/2018           NaN        True
# 3             English  30-36 years        1/1/2018           NaN        True
# 4             English  36-45 years        1/1/2018           NaN        True
# ..                ...          ...             ...           ...         ...
# 95            English   0-18 years        1/5/2018     2/17/2018       False
# 96            English   0-18 years        1/5/2018     2/17/2018       False
# 97            English  19-24 years        1/5/2018     4/14/2018       False
# 98            English  19-24 years        1/5/2018     4/14/2018       False
# 99            English  24-30 years        1/5/2018     1/11/2018       False
#
# [100 rows x 10 columns]

# %% [markdown]
# `.describe()` provides summary statistics for both numeric and non-numeric data.

# %%
# look at the summary info
campaign.describe()
# Out:
#            user_id date_served marketing_channel test_control converted  \
# count        10037       10021             10022        10037     10022
# unique        7309          31                 5            2         2
# top     a100000882   1/15/2018         House Ads      control     False
# freq            12         789              4733         5091      8946
#
#        language_displayed language_preferred    age_group date_subscribed  \
# count               10037              10037        10037            1856
# unique                  4                  4            7              31
# top               English            English  19-24 years       1/16/2018
# freq                 9793               9275         1682             163
#
#        date_canceled is_retained
# count            577        1856
# unique           115           2
# top         4/2/2018        True
# freq              15        1279

# %%
campaign.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10022 entries, 0 to 10021
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             10022 non-null  object
#  1   date_served         10021 non-null  object
#  2   marketing_channel   10022 non-null  object
#  3   test_control        10022 non-null  object
#  4   converted           10022 non-null  bool
#  5   language_preferred  10022 non-null  object
#  6   age_group           10022 non-null  object
#  7   date_subscribed     1856 non-null   object
#  8   date_canceled       577 non-null    object
#  9   is_retained         1856 non-null   object
# dtypes: bool(1), object(9)
# memory usage: 714.6+ KB

# %% [markdown]
#  **Use square brackets to select Dataframes**
#  - single bracket give a Pandas Series
#  - double bracket give a Pandas Dataframe

# %%
campaign['marketing_channel']
# Out:
# 0        House Ads
# 1        House Ads
# 2        House Ads
# 3        House Ads
# 4        House Ads
#            ...
# 10017        Email
# 10018        Email
# 10019    Instagram
# 10020        Email
# 10021     Facebook
# Name: marketing_channel, Length: 10022, dtype: object

# %%
campaign[["marketing_channel"]]
# Out:
#       marketing_channel
# 0             House Ads
# 1             House Ads
# 2             House Ads
# 3             House Ads
# 4             House Ads
# ...                 ...
# 10017             Email
# 10018             Email
# 10019         Instagram
# 10020             Email
# 10021          Facebook
#
# [10022 rows x 1 columns]

# %% [markdown]
# Check **duplicate** records for primary key column
# - think about why duplicates could happen?

# %%
len(campaign["user_id"])
# Out:
# 10022

# %%
campaign['user_id']
# Out:
# 0        a100000029
# 1        a100000030
# 2        a100000031
# 3        a100000032
# 4        a100000033
# 5        a100000034
# 6        a100000035
# 7        a100000036
# 8        a100000037
# 9        a100000038
# 10       a100000039
# 11       a100000040
# 12       a100000041
# 13       a100000042
# 14       a100000043
# 15       a100000044
# 16       a100000045
# 17       a100000046
# 18       a100000047
# 19       a100000048
# 20       a100000049
# 21       a100000050
# 22       a100000050
# 23       a100000051
# 24       a100000051
# 25       a100000052
# 26       a100000052
# 27       a100000053
# 28       a100000053
# 29       a100000054
#             ...
# 10007    a100007265
# 10008    a100007266
# 10009    a100007267
# 10010    a100007268
# 10011    a100007269
# 10012    a100007270
# 10013    a100007271
# 10014    a100007272
# 10015    a100007273
# 10016    a100007274
# 10017    a100007275
# 10018    a100007276
# 10019    a100007277
# 10020    a100007278
# 10021    a100007279
# 10022    a100007280
# 10023    a100007281
# 10024    a100007282
# 10025    a100007283
# 10026    a100007284
# 10027    a100007285
# 10028    a100007286
# 10029    a100007287
# 10030    a100007288
# 10031    a100007289
# 10032    a100007290
# 10033    a100007291
# 10034    a100007292
# 10035    a100007293
# 10036    a100007294
# Name: user_id, Length: 10037, dtype: object

# %%
campaign["user_id"].unique()
# Out:
# array(['a100000029', 'a100000030', 'a100000031', ..., 'a100007292',
#        'a100007293', 'a100007294'], dtype=object)

# %%
len(campaign["user_id"].unique())
# Out:
# 7309

# %% [markdown]
# Use **DataFrame.nunique** to count distinct observations over requested axis (default is 0 for row-wise)

# %%
campaign["user_id"].nunique()
# Out:
# 7309

# %% [markdown]
# For categorical fields or numeric fields with a small number of values, you can use `value_counts()` to see unique values and their frequency.

# %%
campaign["marketing_channel"].value_counts()  # select marketing-channel, count(*) from campaign group by 1;
# Out:
# House Ads    4733
# Instagram    1871
# Facebook     1860
# Push          993
# Email         565
# Name: marketing_channel, dtype: int64

# %% [markdown]
# If you don't care about the frequency and just want an easily readable list of the values from a categorical field, use .unique()

# %%
campaign["marketing_channel"].unique()
# Out:
# array(['House Ads', 'Push', 'Facebook', 'Instagram', 'Email', nan],
#       dtype=object)

# %%
campaign.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10037 entries, 0 to 10036
# Data columns (total 11 columns):
# user_id               10037 non-null object
# date_served           10021 non-null object
# marketing_channel     10022 non-null object
# test_control          10037 non-null object
# converted             10022 non-null object
# language_displayed    10037 non-null object
# language_preferred    10037 non-null object
# age_group             10037 non-null object
# date_subscribed       1856 non-null object
# date_canceled         577 non-null object
# is_retained           1856 non-null object
# dtypes: object(11)
# memory usage: 862.6+ KB

# %% [markdown]
# `.isnull()` is a method that returns true if values are null.
#
# The code below:
# 1. Creates a boolean dataframe with True for null values and False for non-null values
# 2. Sums the number of True's by column (in python True=1 and False=0)

# %%
campaign.isnull()
# Out:
#        user_id  date_served  marketing_channel  test_control  converted  \
# 0        False        False              False         False      False
# 1        False        False              False         False      False
# 2        False        False              False         False      False
# 3        False        False              False         False      False
# 4        False        False              False         False      False
# 5        False        False              False         False      False
# 6        False        False              False         False      False
# 7        False        False              False         False      False
# 8        False        False              False         False      False
# 9        False        False              False         False      False
# 10       False        False              False         False      False
# 11       False        False              False         False      False
# 12       False        False              False         False      False
# 13       False        False              False         False      False
# 14       False        False              False         False      False
# 15       False        False              False         False      False
# 16       False        False              False         False      False
# 17       False        False              False         False      False
# 18       False        False              False         False      False
# 19       False        False              False         False      False
# 20       False        False              False         False      False
# 21       False        False              False         False      False
# 22       False        False              False         False      False
# 23       False        False              False         False      False
# 24       False        False              False         False      False
# 25       False        False              False         False      False
# 26       False        False              False         False      False
# 27       False        False              False         False      False
# 28       False        False              False         False      False
# 29       False        False              False         False      False
# ...        ...          ...                ...           ...        ...
# 10007    False        False              False         False      False
# 10008    False        False              False         False      False
# 10009    False        False              False         False      False
# 10010    False        False              False         False      False
# 10011    False        False              False         False      False
# 10012    False        False              False         False      False
# 10013    False        False              False         False      False
# 10014    False        False              False         False      False
# 10015    False        False              False         False      False
# 10016    False        False              False         False      False
# 10017    False        False              False         False      False
# 10018    False        False              False         False      False
# 10019    False        False              False         False      False
# 10020    False        False              False         False      False
# 10021    False        False              False         False      False
# 10022    False        False              False         False      False
# 10023    False        False              False         False      False
# 10024    False        False              False         False      False
# 10025    False        False              False         False      False
# 10026    False        False              False         False      False
# 10027    False        False              False         False      False
# 10028    False        False              False         False      False
# 10029    False        False              False         False      False
# 10030    False        False              False         False      False
# 10031    False        False              False         False      False
# 10032    False        False              False         False      False
# 10033    False        False              False         False      False
# 10034    False        False              False         False      False
# 10035    False        False              False         False      False
# 10036    False        False              False         False      False
#
#        language_displayed  language_preferred  age_group  date_subscribed  \
# 0                   False               False      False            False
# 1                   False               False      False            False
# 2                   False               False      False            False
# 3                   False               False      False            False
# 4                   False               False      False            False
# 5                   False               False      False            False
# 6                   False               False      False            False
# 7                   False               False      False            False
# 8                   False               False      False            False
# 9                   False               False      False            False
# 10                  False               False      False            False
# 11                  False               False      False            False
# 12                  False               False      False            False
# 13                  False               False      False            False
# 14                  False               False      False            False
# 15                  False               False      False            False
# 16                  False               False      False            False
# 17                  False               False      False            False
# 18                  False               False      False            False
# 19                  False               False      False            False
# 20                  False               False      False            False
# 21                  False               False      False            False
# 22                  False               False      False            False
# 23                  False               False      False            False
# 24                  False               False      False            False
# 25                  False               False      False            False
# 26                  False               False      False            False
# 27                  False               False      False            False
# 28                  False               False      False            False
# 29                  False               False      False            False
# ...                   ...                 ...        ...              ...
# 10007               False               False      False            False
# 10008               False               False      False            False
# 10009               False               False      False            False
# 10010               False               False      False            False
# 10011               False               False      False            False
# 10012               False               False      False            False
# 10013               False               False      False            False
# 10014               False               False      False            False
# 10015               False               False      False            False
# 10016               False               False      False            False
# 10017               False               False      False            False
# 10018               False               False      False            False
# 10019               False               False      False            False
# 10020               False               False      False            False
# 10021               False               False      False            False
# 10022               False               False      False            False
# 10023               False               False      False            False
# 10024               False               False      False            False
# 10025               False               False      False            False
# 10026               False               False      False            False
# 10027               False               False      False            False
# 10028               False               False      False            False
# 10029               False               False      False            False
# 10030               False               False      False            False
# 10031               False               False      False            False
# 10032               False               False      False            False
# 10033               False               False      False            False
# 10034               False               False      False            False
# 10035               False               False      False            False
# 10036               False               False      False            False
#
#        date_canceled  is_retained
# 0               True        False
# 1               True        False
# 2               True        False
# 3               True        False
# 4               True        False
# 5               True        False
# 6               True        False
# 7               True        False
# 8               True        False
# 9               True        False
# 10              True        False
# 11             False        False
# 12             False        False
# 13             False        False
# 14             False        False
# 15             False        False
# 16             False        False
# 17             False        False
# 18             False        False
# 19             False        False
# 20              True        False
# 21              True        False
# 22              True        False
# 23              True        False
# 24              True        False
# 25              True        False
# 26              True        False
# 27              True        False
# 28              True        False
# 29              True        False
# ...              ...          ...
# 10007           True        False
# 10008           True        False
# 10009           True        False
# 10010           True        False
# 10011           True        False
# 10012           True        False
# 10013           True        False
# 10014           True        False
# 10015           True        False
# 10016           True        False
# 10017           True        False
# 10018           True        False
# 10019           True        False
# 10020           True        False
# 10021           True        False
# 10022           True        False
# 10023           True        False
# 10024          False        False
# 10025          False        False
# 10026          False        False
# 10027          False        False
# 10028          False        False
# 10029          False        False
# 10030          False        False
# 10031          False        False
# 10032          False        False
# 10033           True        False
# 10034           True        False
# 10035           True        False
# 10036           True        False
#
# [10037 rows x 11 columns]

# %% [markdown]
# ### Number of Missing records in each column:

# %%
campaign.isnull().sum()
# Out:
# user_id                  0
# date_served             16
# marketing_channel       15
# test_control             0
# converted               15
# language_displayed       0
# language_preferred       0
# age_group                0
# date_subscribed       8181
# date_canceled         9460
# is_retained           8181
# dtype: int64

# %% [markdown]
# #### Practice 1
# For the below exercise, we want you to use the techniques taught above to explore another dataset
#
# Step 1. Create a dataframe called campaign_new from the csv file **campaign_new.csv**
#
# Step 2 How many rows and columns does the data have?
#
# Step 3 Display the top 10 records to explore the data
#
# Step 4 Whether there are duplicates user_id - think about why there are duplicates
#
# Step 5 How many users' MARKETING_CHANNEL are Facebook?
#
# Step 6 How many users' MARKETING_CHANNEL are missing?

# %% [markdown]
# ### 2. Campaign result overview

# %% [markdown]
# **.Groupby**, similar to Group by in SQL, it lets you group data, which is very powerful for analysis. A few things to know:
#
# .groupby() returns a groupby object which then needs to be aggregated with count, sum, mean, median etc.
# By default, .groupby() turns the column you group on into the index for the grouped data
# .groupby() excludes missings!
# The format for .groupby() is dataframe.groupby("column to group on")["column to summarize"].summary_function(). Both the "column to group on" and the "column to summarize" arguments can take more than one column if you input them as a list.
#
# Some summary functions:
#
# sum(), mean(), median(), min(), count(), max()

# %% [markdown]
# #### 2.1 How many users receive marketing offers by day?

# %%
#Group by date_served
daily_users = campaign.groupby(['date_served'])['user_id'].nunique()

# %%
campaign.groupby(['date_served'])['user_id'].nunique() # select date_served, count(distinct user_id) from 
                                                      # campaign group by date_served;
# Out:
# date_served
# 1/1/2018     362
# 1/10/2018    337
# 1/11/2018    310
# 1/12/2018    301
# 1/13/2018    306
# 1/14/2018    305
# 1/15/2018    767
# 1/16/2018    388
# 1/17/2018    369
# 1/18/2018    318
# 1/19/2018    305
# 1/2/2018     374
# 1/20/2018    311
# 1/21/2018    229
# 1/22/2018    178
# 1/23/2018    172
# 1/24/2018    190
# 1/25/2018    184
# 1/26/2018    222
# 1/27/2018    320
# 1/28/2018    320
# 1/29/2018    319
# 1/3/2018     348
# 1/30/2018    317
# 1/31/2018    340
# 1/4/2018     323
# 1/5/2018     319
# 1/6/2018     308
# 1/7/2018     275
# 1/8/2018     312
# 1/9/2018     312
# Name: user_id, dtype: int64

# %%
print(daily_users)
# Out:
# date_served
# 1/1/2018     362
# 1/10/2018    337
# 1/11/2018    310
# 1/12/2018    301
# 1/13/2018    306
# 1/14/2018    305
# 1/15/2018    767
# 1/16/2018    388
# 1/17/2018    369
# 1/18/2018    318
# 1/19/2018    305
# 1/2/2018     374
# 1/20/2018    311
# 1/21/2018    229
# 1/22/2018    178
# 1/23/2018    172
# 1/24/2018    190
# 1/25/2018    184
# 1/26/2018    222
# 1/27/2018    320
# 1/28/2018    320
# 1/29/2018    319
# 1/3/2018     348
# 1/30/2018    317
# 1/31/2018    340
# 1/4/2018     323
# 1/5/2018     319
# 1/6/2018     308
# 1/7/2018     275
# 1/8/2018     312
# 1/9/2018     312
# Name: user_id, dtype: int64

# %% [markdown]
# DataFrame.nunique(): Count distinct observations over requested axis.

# %% [markdown]
# Visualization in Python

# %%
import matplotlib.pyplot as plt

# plot
daily_users.plot()

# annotate
plt.title('daily number of users seeing the ads')
plt.xlabel('Date')
plt.ylabel('Number of users')
plt.show()

# %% [markdown]
# #### Practice 2
# What is the overall conversion rate? hint: use column 'converted'

# %% [markdown]
# #### 2.2 Common marketing metrics to evaluate campaign performance
# - **Conversion rate** = Number of people who converted / Total number of people who received offers
# - **Retention rate** = number of people who remained / Total number of people who converted

# %% [markdown]
# Filter in Pandas:

# %%
# Step one: create a boolean mask
campaign['is_retained']==True
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
#          ...
# 10007     True
# 10008     True
# 10009     True
# 10010     True
# 10011     True
# 10012     True
# 10013     True
# 10014     True
# 10015     True
# 10016     True
# 10017     True
# 10018     True
# 10019     True
# 10020     True
# 10021     True
# 10022     True
# 10023     True
# 10024    False
# 10025    False
# 10026    False
# 10027    False
# 10028    False
# 10029    False
# 10030    False
# 10031    False
# 10032    False
# 10033     True
# 10034     True
# 10035     True
# 10036     True
# Name: is_retained, Length: 10037, dtype: bool

# %%
# Step two: put the boolean mask into the dataframe
campaign.loc[campaign['is_retained']==True]    #select * from campaign where is_retained = True
# Out:
#           user_id date_served marketing_channel     test_control converted  \
# 0      a100000029    1/1/2018         House Ads  personalization      True
# 1      a100000030    1/1/2018         House Ads  personalization      True
# 2      a100000031    1/1/2018         House Ads  personalization      True
# 3      a100000032    1/1/2018         House Ads  personalization      True
# 4      a100000033    1/1/2018         House Ads  personalization      True
# 5      a100000034    1/1/2018         House Ads  personalization      True
# 6      a100000035    1/1/2018         House Ads  personalization      True
# 7      a100000036    1/1/2018         House Ads  personalization      True
# 8      a100000037    1/1/2018         House Ads  personalization      True
# 9      a100000038    1/1/2018         House Ads  personalization      True
# 10     a100000039    1/1/2018         House Ads  personalization      True
# 20     a100000049    1/2/2018         House Ads  personalization      True
# 21     a100000050    1/2/2018         House Ads  personalization      True
# 22     a100000050    1/1/2018         House Ads  personalization     False
# 23     a100000051    1/2/2018         House Ads  personalization      True
# 24     a100000051    1/1/2018              Push  personalization     False
# 25     a100000052    1/2/2018         House Ads  personalization      True
# 26     a100000052    1/1/2018         House Ads  personalization     False
# 27     a100000053    1/2/2018         House Ads  personalization      True
# 28     a100000053    1/1/2018         House Ads  personalization     False
# 29     a100000054    1/2/2018         House Ads  personalization      True
# 30     a100000054    1/1/2018         House Ads  personalization     False
# 31     a100000055    1/2/2018         House Ads  personalization      True
# 32     a100000055    1/1/2018              Push  personalization     False
# 33     a100000056    1/2/2018         House Ads  personalization      True
# 34     a100000056    1/1/2018          Facebook  personalization     False
# 35     a100000057    1/2/2018         House Ads  personalization      True
# 36     a100000057    1/1/2018         Instagram  personalization     False
# 37     a100000058    1/2/2018         House Ads  personalization      True
# 38     a100000058    1/1/2018         Instagram  personalization     False
# ...           ...         ...               ...              ...       ...
# 9998   a100007256   1/15/2018             Email  personalization      True
# 9999   a100007257   1/15/2018             Email  personalization      True
# 10000  a100007258   1/15/2018             Email  personalization     False
# 10001  a100007259   1/16/2018             Email  personalization      True
# 10002  a100007260   1/16/2018             Email  personalization      True
# 10003  a100007261   1/16/2018             Email  personalization      True
# 10004  a100007262   1/16/2018             Email  personalization      True
# 10005  a100007263   1/16/2018             Email  personalization      True
# 10006  a100007264   1/16/2018             Email  personalization      True
# 10007  a100007265   1/16/2018             Email  personalization      True
# 10008  a100007266   1/16/2018             Email  personalization     False
# 10009  a100007267   1/16/2018             Email  personalization      True
# 10010  a100007268   1/16/2018             Email  personalization      True
# 10011  a100007269   1/16/2018             Email  personalization      True
# 10012  a100007270   1/16/2018             Email  personalization      True
# 10013  a100007271   1/16/2018             Email  personalization      True
# 10014  a100007272   1/16/2018             Email  personalization      True
# 10015  a100007273   1/16/2018             Email  personalization      True
# 10016  a100007274   1/16/2018             Email  personalization      True
# 10017  a100007275   1/16/2018             Email  personalization      True
# 10018  a100007276   1/16/2018             Email  personalization      True
# 10019  a100007277   1/16/2018             Email  personalization      True
# 10020  a100007278   1/16/2018             Email          control     False
# 10021  a100007279   1/16/2018             Email          control      True
# 10022  a100007280   1/17/2018             Email          control      True
# 10023  a100007281   1/17/2018             Email          control      True
# 10033  a100007291   1/17/2018             Email          control      True
# 10034  a100007292    1/5/2018         Instagram          control     False
# 10035  a100007293   1/17/2018             Email          control      True
# 10036  a100007294    1/6/2018          Facebook          control     False
#
#       language_displayed language_preferred    age_group date_subscribed  \
# 0                English            English   0-18 years        1/1/2018
# 1                English            English  19-24 years        1/1/2018
# 2                English            English  24-30 years        1/1/2018
# 3                English            English  30-36 years        1/1/2018
# 4                English            English  36-45 years        1/1/2018
# 5                 German             German  45-55 years        1/1/2018
# 6                English            English    55+ years        1/1/2018
# 7                English            English   0-18 years        1/1/2018
# 8                English            English  19-24 years        1/1/2018
# 9                English            English  24-30 years        1/1/2018
# 10               English            English   0-18 years        1/1/2018
# 20                German             German  19-24 years        1/2/2018
# 21               English            English  24-30 years        1/2/2018
# 22               English            English  24-30 years        1/2/2018
# 23               English            English  30-36 years        1/2/2018
# 24               English            English  30-36 years        1/2/2018
# 25               English            English  36-45 years        1/2/2018
# 26               English            English  36-45 years        1/2/2018
# 27               English            English  45-55 years        1/2/2018
# 28               English            English  45-55 years        1/2/2018
# 29               English            English    55+ years        1/2/2018
# 30               English            English    55+ years        1/2/2018
# 31               English            English   0-18 years        1/2/2018
# 32               English            English   0-18 years        1/2/2018
# 33               English            English  19-24 years        1/2/2018
# 34               English            English  19-24 years        1/2/2018
# 35               English            English  24-30 years        1/2/2018
# 36               English            English  24-30 years        1/2/2018
# 37               English            English   0-18 years        1/2/2018
# 38               English            English   0-18 years        1/2/2018
# ...                  ...                ...          ...             ...
# 9998              German             German   0-18 years       1/15/2018
# 9999              German             German  19-24 years       1/15/2018
# 10000             German             German  24-30 years       1/15/2018
# 10001             German             German  24-30 years       1/16/2018
# 10002             German             German   0-18 years       1/16/2018
# 10003             German             German  19-24 years       1/16/2018
# 10004             German             German  24-30 years       1/16/2018
# 10005             German             German  24-30 years       1/16/2018
# 10006             German             German   0-18 years       1/16/2018
# 10007             German             German  19-24 years       1/16/2018
# 10008             German             German  24-30 years       1/16/2018
# 10009             German             German  24-30 years       1/16/2018
# 10010             German             German   0-18 years       1/16/2018
# 10011             German             German  19-24 years       1/16/2018
# 10012             German             German  24-30 years       1/16/2018
# 10013             German             German  24-30 years       1/16/2018
# 10014             German             German   0-18 years       1/16/2018
# 10015             German             German  19-24 years       1/16/2018
# 10016             German             German  24-30 years       1/16/2018
# 10017             German             German  24-30 years       1/16/2018
# 10018             German             German   0-18 years       1/16/2018
# 10019             German             German  19-24 years       1/16/2018
# 10020             German             German   0-18 years       1/16/2018
# 10021             German             German  19-24 years       1/16/2018
# 10022             German             German  24-30 years       1/17/2018
# 10023             German             German  30-36 years       1/17/2018
# 10033             German             German    55+ years       1/17/2018
# 10034             German             German    55+ years       1/17/2018
# 10035             German             German   0-18 years       1/17/2018
# 10036             German             German   0-18 years       1/17/2018
#
#       date_canceled is_retained
# 0               NaN        True
# 1               NaN        True
# 2               NaN        True
# 3               NaN        True
# 4               NaN        True
# 5               NaN        True
# 6               NaN        True
# 7               NaN        True
# 8               NaN        True
# 9               NaN        True
# 10              NaN        True
# 20              NaN        True
# 21              NaN        True
# 22              NaN        True
# 23              NaN        True
# 24              NaN        True
# 25              NaN        True
# 26              NaN        True
# 27              NaN        True
# 28              NaN        True
# 29              NaN        True
# 30              NaN        True
# 31              NaN        True
# 32              NaN        True
# 33              NaN        True
# 34              NaN        True
# 35              NaN        True
# 36              NaN        True
# 37              NaN        True
# 38              NaN        True
# ...             ...         ...
# 9998            NaN        True
# 9999            NaN        True
# 10000           NaN        True
# 10001           NaN        True
# 10002           NaN        True
# 10003           NaN        True
# 10004           NaN        True
# 10005           NaN        True
# 10006           NaN        True
# 10007           NaN        True
# 10008           NaN        True
# 10009           NaN        True
# 10010           NaN        True
# 10011           NaN        True
# 10012           NaN        True
# 10013           NaN        True
# 10014           NaN        True
# 10015           NaN        True
# 10016           NaN        True
# 10017           NaN        True
# 10018           NaN        True
# 10019           NaN        True
# 10020           NaN        True
# 10021           NaN        True
# 10022           NaN        True
# 10023           NaN        True
# 10033           NaN        True
# 10034           NaN        True
# 10035           NaN        True
# 10036           NaN        True
#
# [1279 rows x 11 columns]

# %%
retained = campaign.loc[campaign['is_retained']==True]['user_id'].nunique()

# %%
print(retained)
# Out:
# 678

# %%
converted = campaign.loc[campaign['converted']==True]['user_id'].nunique()

# %%
print(converted)
# Out:
# 1015

# %%
retention_rate = retained / converted

# %%
print(round(retention_rate,2))
# Out:
# 0.67

# %% [markdown]
# #### 2.3 Customer Segmentation analysis
#  - Use segemetnation analysis to
#      - Analyze campaign performance by each segments
#      - Target profitable segments for next campaign
#
#  - Creating segmentation variables is the first step - usually this will happen in SQL

# %%
# Look at by marketing channel:
campaign.groupby(['marketing_channel'])['user_id'].nunique()
# Out:
# marketing_channel
# Email         553
# Facebook     1758
# House Ads    3968
# Instagram    1740
# Push          972
# Name: user_id, dtype: int64

# %%
# How many customers are converted in each marketing channel
campaign.loc[campaign['converted']==True].groupby(['marketing_channel'])['user_id'].nunique()
# Out:
# marketing_channel
# Email        187
# Facebook     221
# House Ads    298
# Instagram    232
# Push          77
# Name: user_id, dtype: int64

# %% [markdown]
# Conversion rate by channel

# %%
conversion_by_channel = campaign.loc[campaign['converted']==True].groupby(['marketing_channel'])['user_id'].nunique() / \
campaign.groupby(['marketing_channel'])['user_id'].nunique()

# %%
print(conversion_by_channel)
# Out:
# marketing_channel
# Email        0.338156
# Facebook     0.125711
# House Ads    0.075101
# Instagram    0.133333
# Push         0.079218
# Name: user_id, dtype: float64

# %%
#plot conversion rate by channel:

import matplotlib.pyplot as plt

# plot
conversion_by_channel.plot(kind='bar')

# annotate
plt.title('conversion rate by channel')
plt.xlabel('marketing channel')
plt.ylabel('conversion rate')
plt.show()

# %% [markdown]
# #### Practice 3
# What is the retention rate by each marketing channel?

# %% [markdown]
# ##### 2.3.2 Customer Segmentation analysis by more than one segments

# %%
language_age_convert=campaign.loc[campaign['converted']==True].groupby(['language_preferred', 'age_group'])['user_id'].nunique()

# %%
print(language_age_convert)

# %% [markdown]
# Unstack the result to a DataFrame, so that we can plot

# %%
language_age_convert.unstack(level=1)

# %%
df_language_age_convert=pd.DataFrame(language_age_convert.unstack(level=1))

# %%
print(df_language_age_convert)

# %%
# plot
df_language_age_convert.plot(kind='bar')

# annotate
plt.title('number of users by language and age')
plt.xlabel('language')
plt.ylabel('number of users')
plt.show()

# %% [markdown]
# #### Practice 4
# Looking at the number of **converted users** by these 2 segments are not very informative.
#
# Should we look at conversion rate by language and age?

# %% [markdown]
# ### 3. A/B Testing
#
# What is A/B testing:
#
# - A/B testing, sometimes referred to as split testing, is the process of comparing two different marketing strategies to determine which one performs better
# - Testing allows us to understand marketing impact

# %% [markdown]
# In a typical A/B testing setting, you would create and test two or more versions of marketing strategies for their effectiveness in achieving your marketing goal. Consider a case where your goal is to improve marketing email open rates.
#
# If your hypothesis is that email subject line B will result in higher open rates than email subject line A, then you would run an A/B test with these two subject lines. You will randomly select half of the users and send out marketing emails with subject line A. The other half of randomly selected users will receive emails with subject line B. You will run this test for a predetermined period of time (which could be one week, two weeks, or one month, for instance) or until a predetermined number of users receive the two versions of emails (which is a minimum of 1,000 users to receive each version of the subject line). Once your tests are complete, then you analyze and evaluate the experiment results. When analyzing the results, you will need to check whether there is a statistically significant difference between the results of the two versions.

# %%
from scipy import stats
import numpy as np

# %%
campaign['test_control'].value_counts()
# Out:
# control            5091
# personalization    4946
# Name: test_control, dtype: int64

# %%
# Let's only look at Email marketing channel
email = campaign.loc[campaign['marketing_channel'] == 'Email']

# %%
print(email)
# Out:
#           user_id date_served marketing_channel     test_control converted  \
# 354    a100000526    1/1/2018             Email  personalization      True
# 358    a100000530    1/5/2018             Email  personalization      True
# 362    a100000534    1/9/2018             Email  personalization     False
# 366    a100000538   1/13/2018             Email  personalization      True
# 370    a100000542   1/17/2018             Email  personalization      True
# 374    a100000546   1/21/2018             Email  personalization      True
# 378    a100000550   1/25/2018             Email  personalization      True
# 382    a100000554   1/29/2018             Email  personalization     False
# 386    a100000558    1/2/2018             Email  personalization      True
# 390    a100000562    1/6/2018             Email  personalization     False
# 467    a100000628   1/30/2018             Email  personalization      True
# 468    a100000628   1/30/2018             Email  personalization     False
# 469    a100000629   1/15/2018             Email  personalization      True
# 470    a100000629   1/15/2018             Email  personalization      True
# 471    a100000630   1/15/2018             Email  personalization      True
# 472    a100000630   1/15/2018             Email  personalization     False
# 473    a100000631   1/15/2018             Email  personalization      True
# 474    a100000631   1/15/2018             Email  personalization     False
# 475    a100000632   1/15/2018             Email  personalization      True
# 476    a100000632   1/15/2018             Email  personalization     False
# 477    a100000633   1/15/2018             Email  personalization      True
# 478    a100000633   1/15/2018             Email  personalization      True
# 479    a100000634   1/15/2018             Email  personalization      True
# 480    a100000635   1/15/2018             Email  personalization     False
# 481    a100000636   1/15/2018             Email  personalization      True
# 482    a100000637   1/15/2018             Email  personalization      True
# 483    a100000638   1/15/2018             Email  personalization     False
# 484    a100000639   1/15/2018             Email  personalization      True
# 485    a100000640   1/15/2018             Email  personalization      True
# 486    a100000641   1/15/2018             Email  personalization      True
# ...           ...         ...               ...              ...       ...
# 10005  a100007263   1/16/2018             Email  personalization      True
# 10006  a100007264   1/16/2018             Email  personalization      True
# 10007  a100007265   1/16/2018             Email  personalization      True
# 10008  a100007266   1/16/2018             Email  personalization     False
# 10009  a100007267   1/16/2018             Email  personalization      True
# 10010  a100007268   1/16/2018             Email  personalization      True
# 10011  a100007269   1/16/2018             Email  personalization      True
# 10012  a100007270   1/16/2018             Email  personalization      True
# 10013  a100007271   1/16/2018             Email  personalization      True
# 10014  a100007272   1/16/2018             Email  personalization      True
# 10015  a100007273   1/16/2018             Email  personalization      True
# 10016  a100007274   1/16/2018             Email  personalization      True
# 10017  a100007275   1/16/2018             Email  personalization      True
# 10018  a100007276   1/16/2018             Email  personalization      True
# 10019  a100007277   1/16/2018             Email  personalization      True
# 10020  a100007278   1/16/2018             Email          control     False
# 10021  a100007279   1/16/2018             Email          control      True
# 10022  a100007280   1/17/2018             Email          control      True
# 10023  a100007281   1/17/2018             Email          control      True
# 10024  a100007282   1/17/2018             Email          control      True
# 10025  a100007283   1/17/2018             Email          control      True
# 10026  a100007284   1/17/2018             Email          control      True
# 10027  a100007285   1/17/2018             Email          control      True
# 10028  a100007286   1/17/2018             Email          control      True
# 10029  a100007287   1/17/2018             Email          control      True
# 10030  a100007288   1/17/2018             Email          control      True
# 10031  a100007289   1/17/2018             Email          control      True
# 10032  a100007290   1/17/2018             Email          control      True
# 10033  a100007291   1/17/2018             Email          control      True
# 10035  a100007293   1/17/2018             Email          control      True
#
#       language_displayed language_preferred    age_group date_subscribed  \
# 354               Arabic             Arabic   0-18 years        1/1/2018
# 358               Arabic             Arabic  19-24 years        1/5/2018
# 362              English            English  45-55 years        1/9/2018
# 366               Arabic             Arabic  24-30 years       1/13/2018
# 370              English            English   0-18 years       1/17/2018
# 374              English            English  19-24 years       1/21/2018
# 378              English            English  24-30 years       1/25/2018
# 382              English            English  30-36 years       1/29/2018
# 386              English            English   0-18 years        1/2/2018
# 390              English            English  19-24 years        1/6/2018
# 467              English            English  24-30 years       1/30/2018
# 468              English            English  24-30 years       1/30/2018
# 469              English            English   0-18 years       1/15/2018
# 470              English            English   0-18 years       1/15/2018
# 471              English            English  19-24 years       1/15/2018
# 472              English            English  19-24 years       1/15/2018
# 473              English            English  24-30 years       1/15/2018
# 474              English            English  24-30 years       1/15/2018
# 475              English            English  24-30 years       1/15/2018
# 476              English            English  24-30 years       1/15/2018
# 477              English            English   0-18 years       1/15/2018
# 478              English            English   0-18 years       1/15/2018
# 479              English            English  19-24 years       1/15/2018
# 480              English            English  24-30 years       1/15/2018
# 481              English            English  24-30 years       1/15/2018
# 482              English            English   0-18 years       1/15/2018
# 483              English            English  19-24 years       1/15/2018
# 484              English            English  24-30 years       1/15/2018
# 485              English            English  24-30 years       1/15/2018
# 486              English            English   0-18 years       1/15/2018
# ...                  ...                ...          ...             ...
# 10005             German             German  24-30 years       1/16/2018
# 10006             German             German   0-18 years       1/16/2018
# 10007             German             German  19-24 years       1/16/2018
# 10008             German             German  24-30 years       1/16/2018
# 10009             German             German  24-30 years       1/16/2018
# 10010             German             German   0-18 years       1/16/2018
# 10011             German             German  19-24 years       1/16/2018
# 10012             German             German  24-30 years       1/16/2018
# 10013             German             German  24-30 years       1/16/2018
# 10014             German             German   0-18 years       1/16/2018
# 10015             German             German  19-24 years       1/16/2018
# 10016             German             German  24-30 years       1/16/2018
# 10017             German             German  24-30 years       1/16/2018
# 10018             German             German   0-18 years       1/16/2018
# 10019             German             German  19-24 years       1/16/2018
# 10020             German             German   0-18 years       1/16/2018
# 10021             German             German  19-24 years       1/16/2018
# 10022             German             German  24-30 years       1/17/2018
# 10023             German             German  30-36 years       1/17/2018
# 10024             German             German  36-45 years       1/17/2018
# 10025             German             German  45-55 years       1/17/2018
# 10026             German             German    55+ years       1/17/2018
# 10027             German             German   0-18 years       1/17/2018
# 10028             German             German  19-24 years       1/17/2018
# 10029             German             German  24-30 years       1/17/2018
# 10030             German             German  30-36 years       1/17/2018
# 10031             German             German  36-45 years       1/17/2018
# 10032             German             German  45-55 years       1/17/2018
# 10033             German             German    55+ years       1/17/2018
# 10035             German             German   0-18 years       1/17/2018
#
#       date_canceled is_retained
# 354             NaN        True
# 358             NaN        True
# 362             NaN        True
# 366       1/23/2018       False
# 370       2/12/2018       False
# 374             NaN        True
# 378             NaN        True
# 382             NaN        True
# 386       3/26/2018       False
# 390       2/15/2018       False
# 467             NaN        True
# 468             NaN        True
# 469             NaN        True
# 470             NaN        True
# 471             NaN        True
# 472             NaN        True
# 473             NaN        True
# 474             NaN        True
# 475             NaN        True
# 476             NaN        True
# 477             NaN        True
# 478             NaN        True
# 479        2/9/2018       False
# 480       3/15/2018       False
# 481        4/8/2018       False
# 482       4/17/2018       False
# 483       1/30/2018       False
# 484       3/19/2018       False
# 485       2/28/2018       False
# 486        2/7/2018       False
# ...             ...         ...
# 10005           NaN        True
# 10006           NaN        True
# 10007           NaN        True
# 10008           NaN        True
# 10009           NaN        True
# 10010           NaN        True
# 10011           NaN        True
# 10012           NaN        True
# 10013           NaN        True
# 10014           NaN        True
# 10015           NaN        True
# 10016           NaN        True
# 10017           NaN        True
# 10018           NaN        True
# 10019           NaN        True
# 10020           NaN        True
# 10021           NaN        True
# 10022           NaN        True
# 10023           NaN        True
# 10024     2/25/2018       False
# 10025      4/5/2018       False
# 10026     2/12/2018       False
# 10027      4/4/2018       False
# 10028      3/5/2018       False
# 10029     2/14/2018       False
# 10030     4/26/2018       False
# 10031     1/27/2018       False
# 10032     1/24/2018       False
# 10033           NaN        True
# 10035           NaN        True
#
# [565 rows x 11 columns]

# %% [markdown]
# For email channel, there are the test groups which received personalization email and the control group which receive normal email

# %%
email.groupby(['test_control'])['user_id'].nunique()
# Out:
# test_control
# control            270
# personalization    284
# Name: user_id, dtype: int64

# %%
# Let's compare the conversion rate between test and control group
email.loc[email['converted']==True].groupby(['test_control'])['user_id'].nunique()
# Out:
# test_control
# control             76
# personalization    111
# Name: user_id, dtype: int64

# %%
email.loc[email['converted']==True].groupby(['test_control'])['user_id'].nunique()\
/email.groupby(['test_control'])['user_id'].nunique()
# Out:
# test_control
# control            0.281481
# personalization    0.390845
# Name: user_id, dtype: float64

# %% [markdown]
# Calculate the lift:
#
# (Test conversion rate - Control conversion rate) / Control converstion rate

# %%
(0.40-0.28)/0.28
# Out:
# 0.4285714285714285
